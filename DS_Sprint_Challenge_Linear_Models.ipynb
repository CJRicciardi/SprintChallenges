# %% [markdown]
# _Lambda School Data Science, Unit 2_
#
# # Linear Models Sprint Challenge
#
# To demonstrate mastery on your Sprint Challenge, do all the required, numbered instructions in this notebook.
#
# To earn a score of "3", also do all the stretch goals.
#
# You are permitted and encouraged to do as much data exploration as you want.

# %% [markdown]
# ### Part 1, Classification
# - 1.1. Do train/test split. Arrange data into X features matrix and y target vector
# - 1.2. Use scikit-learn to fit a logistic regression model
# - 1.3. Report classification metric: accuracy
#
# ### Part 2, Regression
# - 2.1. Begin with baselines for regression
# - 2.2. Do train/validate/test split
# - 2.3. Arrange data into X features matrix and y target vector
# - 2.4. Do one-hot encoding
# - 2.5. Use scikit-learn to fit a linear regression or ridge regression model
# - 2.6. Report validation MAE and $R^2$
#
# ### Stretch Goals, Regression
# - Make at least 2 visualizations to explore relationships between features and target. You may use any visualization library
# - Try at least 3 feature combinations. You may select features manually, or automatically
# - Report validation MAE and $R^2$ for each feature combination you try
# - Report test MAE and $R^2$ for your final model
# - Print or plot the coefficients for the features in your model

# %%
# If you're in Colab...
import sys
if 'google.colab' in sys.modules:
    # !pip install category_encoders==2.*
    # !pip install pandas-profiling==2.*
    # !pip install plotly==4.*

# %% [markdown]
# # Part 1, Classification: Predict Blood Donations 🚑
# Our dataset is from a mobile blood donation vehicle in Taiwan. The Blood Transfusion Service Center drives to different universities and collects blood as part of a blood drive.
#
# The goal is to predict whether the donor made a donation in March 2007, using information about each donor's history.
#
# Good data-driven systems for tracking and predicting donations and supply needs can improve the entire supply chain, making sure that more patients get the blood transfusions they need.

# %%
import pandas as pd

donors = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/blood-transfusion/transfusion.data')
assert donors.shape == (748,5)

donors = donors.rename(columns={
    'Recency (months)': 'months_since_last_donation', 
    'Frequency (times)': 'number_of_donations', 
    'Monetary (c.c. blood)': 'total_volume_donated', 
    'Time (months)': 'months_since_first_donation', 
    'whether he/she donated blood in March 2007': 'made_donation_in_march_2007'
})

# %% [markdown]
# Notice that the majority class (did not donate blood in March 2007) occurs about 3/4 of the time.
#
# This is the accuracy score for the "majority class baseline" (the accuracy score we'd get by just guessing the majority class every time).

# %%
donors['made_donation_in_march_2007'].value_counts(normalize=True)
# Out:
# 0    0.762032
# 1    0.237968
# Name: made_donation_in_march_2007, dtype: float64

# %% [markdown]
# ## 1.1. Do train/test split. Arrange data into X features matrix and y target vector
#
# Do these steps in either order.
#
# Use scikit-learn's train/test split function to split randomly. (You can include 75% of the data in the train set, and hold out 25% for the test set, which is the default.)

# %%
target = 'made_donation_in_march_2007'
features = ['months_since_last_donation', 'number_of_donations',
       'total_volume_donated', 'months_since_first_donation']

# %%
df = donors
df.columns
# Out:
# Index(['months_since_last_donation', 'number_of_donations',
#        'total_volume_donated', 'months_since_first_donation',
#        'made_donation_in_march_2007'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
train, val = train_test_split(df, random_state=7)
train.shape, val.shape
# Out:
# ((561, 5), (187, 5))

# %% [markdown]
# ## 1.2. Use scikit-learn to fit a logistic regression model
#
# You may use any number of features

# %%
x_train = train[features]
y_train = train[target]
x_val = val[features]
y_val = val[target]

# %%
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((561, 4), (187, 4), (561,), (187,))

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)

# %%
model = LogisticRegressionCV()
model.fit(x_train_scaled, y_train)
# Out:
# C:\Users\ricci\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LogisticRegressionCV(Cs=10, class_weight=None, cv='warn', dual=False,
#                      fit_intercept=True, intercept_scaling=1.0, l1_ratios=None,
#                      max_iter=100, multi_class='warn', n_jobs=None,
#                      penalty='l2', random_state=None, refit=True, scoring=None,
#                      solver='lbfgs', tol=0.0001, verbose=0)

# %% [markdown]
# ## 1.3. Report classification metric: accuracy
#
# What is your model's accuracy on the test set?
#
# Don't worry if your model doesn't beat the majority class baseline. That's okay!
#
# _"The combination of some data and an aching desire for an answer does not ensure that a reasonable answer can be extracted from a given body of data."_ —[John Tukey](https://en.wikiquote.org/wiki/John_Tukey)
#
# (Also, if we used recall score instead of accuracy score, then your model would almost certainly beat the baseline. We'll discuss how to choose and interpret evaluation metrics throughout this unit.)

# %%
print(f'Model Accuracy = {model.score(x_val_scaled, y_val):,.4f}')
# Out:
# Model Accuracy = 0.7433

# %% [markdown]
# # Part 2, Regression: Predict home prices in Ames, Iowa 🏠
#
# You'll use historical housing data. ***There's a data dictionary at the bottom of the notebook.***
#
# Run this code cell to load the dataset:

# %%
import pandas as pd
URL = 'https://drive.google.com/uc?export=download&id=1522WlEW6HFss36roD_Cd9nybqSuiVcCK'
homes = pd.read_csv(URL)
assert homes.shape == (2904, 47)

# %% [markdown]
# ## 2.1. Begin with baselines
#
# What is the Mean Absolute Error and R^2 score for a mean baseline? (You can get these estimated scores using all your data, before splitting it.)

# %%
pd.set_option('display.max_columns', 100)

# %%
homes.columns
# Out:
# Index(['1st_Flr_SF', 'Bedroom_AbvGr', 'Bldg_Type', 'Bsmt_Full_Bath',
#        'Bsmt_Half_Bath', 'Central_Air', 'Condition_1', 'Condition_2',
#        'Electrical', 'Exter_Cond', 'Exter_Qual', 'Exterior_1st',
#        'Exterior_2nd', 'Foundation', 'Full_Bath', 'Functional', 'Gr_Liv_Area',
#        'Half_Bath', 'Heating', 'Heating_QC', 'House_Style', 'Kitchen_AbvGr',
#        'Kitchen_Qual', 'Land_Contour', 'Land_Slope', 'Lot_Area', 'Lot_Config',
#        'Lot_Shape', 'MS_SubClass', 'MS_Zoning', 'Mas_Vnr_Type', 'Mo_Sold',
#        'Neighborhood', 'Overall_Cond', 'Overall_Qual', 'Paved_Drive',
#        'Roof_Matl', 'Roof_Style', 'SalePrice', 'Sale_Condition', 'Sale_Type',
#        'Street', 'TotRms_AbvGrd', 'Utilities', 'Year_Built', 'Year_Remod/Add',
#        'Yr_Sold', 'mean'],
#       dtype='object')

# %%
homes['mean'] = (homes['SalePrice'].mean())
homes['mean'].head()
# Out:
# 0    180383.689738
# 1    180383.689738
# 2    180383.689738
# 3    180383.689738
# 4    180383.689738
# Name: mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mean = homes['mean']
sprice = homes['SalePrice']

mse = mean_squared_error(sprice, mean)
rmse = np.sqrt(mse)
mae = mean_absolute_error(sprice, mean)
r2 = r2_score(sprice, mean)
print(f'Mean Squared Error = {mse:,.4f}')
print(f"Root Mean Squared Error = {rmse:,.4f}")
print(f'Mean Absolute Error = {mae:,.4f}')
print(f'R Squared = {r2:,.4f}')
# Out:
# Mean Squared Error = 6,366,297,661.4544
# Root Mean Squared Error = 79,789.0823
# Mean Absolute Error = 58,149.9277
# R Squared = 0.0000

# %% [markdown]
# ## 2.2. Do train/validate/test split
#
# Train on houses sold in the years 2006 - 2008. (1,920 rows)
#
# Validate on house sold in 2009. (644 rows)
#
# Test on houses sold in 2010. (340 rows)

# %%
train = homes[(homes['Yr_Sold'] == 2006) | (homes['Yr_Sold'] == 2007) | (homes['Yr_Sold'] == 2008)]
val = homes[homes['Yr_Sold'] == 2009]
test = homes[homes['Yr_Sold'] == 2010]

train.shape, val.shape, test.shape
# Out:
# ((1920, 48), (644, 48), (340, 48))

# %% [markdown]
# ## 2.3. Arrange data into X features matrix and y target vector
#
# Select at least one numeric feature and at least one categorical feature.
#
# Otherwise, you may choose whichever features and however many you want.

# %%
homes.columns
# Out:
# Index(['1st_Flr_SF', 'Bedroom_AbvGr', 'Bldg_Type', 'Bsmt_Full_Bath',
#        'Bsmt_Half_Bath', 'Central_Air', 'Condition_1', 'Condition_2',
#        'Electrical', 'Exter_Cond', 'Exter_Qual', 'Exterior_1st',
#        'Exterior_2nd', 'Foundation', 'Full_Bath', 'Functional', 'Gr_Liv_Area',
#        'Half_Bath', 'Heating', 'Heating_QC', 'House_Style', 'Kitchen_AbvGr',
#        'Kitchen_Qual', 'Land_Contour', 'Land_Slope', 'Lot_Area', 'Lot_Config',
#        'Lot_Shape', 'MS_SubClass', 'MS_Zoning', 'Mas_Vnr_Type', 'Mo_Sold',
#        'Neighborhood', 'Overall_Cond', 'Overall_Qual', 'Paved_Drive',
#        'Roof_Matl', 'Roof_Style', 'SalePrice', 'Sale_Condition', 'Sale_Type',
#        'Street', 'TotRms_AbvGrd', 'Utilities', 'Year_Built', 'Year_Remod/Add',
#        'Yr_Sold', 'mean'],
#       dtype='object')

# %%
target = 'SalePrice'
features = ['1st_Flr_SF', 'Bedroom_AbvGr', 'Bldg_Type', 'Bsmt_Full_Bath',
       'Bsmt_Half_Bath', 'Central_Air', 'Condition_1', 'Condition_2',
       'Electrical', 'Exter_Cond', 'Exter_Qual', 'Exterior_1st',
       'Exterior_2nd', 'Foundation', 'Full_Bath', 'Functional', 'Gr_Liv_Area',
       'Half_Bath', 'Heating', 'Heating_QC', 'House_Style', 'Kitchen_AbvGr',
       'Kitchen_Qual', 'Land_Contour', 'Land_Slope', 'Lot_Area', 'Lot_Config',
       'Lot_Shape', 'MS_SubClass', 'MS_Zoning', 'Mas_Vnr_Type', 'Mo_Sold',
       'Neighborhood', 'Overall_Cond', 'Overall_Qual', 'Paved_Drive',
       'Roof_Matl', 'Roof_Style', 'Sale_Condition', 'Sale_Type',
       'Street', 'TotRms_AbvGrd', 'Utilities', 'Year_Built', 'Year_Remod/Add',
       'Yr_Sold']
x_train = train[features]
x_val = val[features]
x_test = test[features]
y_train = train[target]
y_val = val[target]
y_test = test[target]

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((1920, 46), (1920,), (644, 46), (644,), (340, 46), (340,))

# %% [markdown]
# ## 2.4. Do one-hot encoding
#
# Encode your categorical feature(s).

# %%
homes.describe(exclude='number').T
# Out:
#                count unique      top  freq
# Bldg_Type       2904      5     1Fam  2401
# Central_Air     2904      2        Y  2708
# Condition_1     2904      9     Norm  2502
# Condition_2     2904      8     Norm  2874
# Electrical      2904      5    SBrkr  2658
# Exter_Cond      2904      5       TA  2523
# Exter_Qual      2904      4       TA  1795
# Exterior_1st    2904     16  VinylSd  1007
# Exterior_2nd    2904     17  VinylSd   996
# Foundation      2904      6    PConc  1286
# Functional      2904      8      Typ  2703
# Heating         2904      6     GasA  2859
# Heating_QC      2904      5       Ex  1473
# House_Style     2904      8   1Story  1467
# Kitchen_Qual    2904      5       TA  1491
# Land_Contour    2904      4      Lvl  2608
# Land_Slope      2904      3      Gtl  2763
# Lot_Config      2904      5   Inside  2123
# Lot_Shape       2904      4      Reg  1846
# MS_Zoning       2904      7       RL  2255
# Mas_Vnr_Type    2904      5     None  1749
# Neighborhood    2904     28    NAmes   443
# Paved_Drive     2904      3        Y  2627
# Roof_Matl       2904      8  CompShg  2861
# Roof_Style      2904      6    Gable  2299
# Sale_Condition  2904      6   Normal  2400
# Sale_Type       2904     10      WD   2522
# Street          2904      2     Pave  2892
# Utilities       2904      3   AllPub  2901

# %%
import category_encoders as ce
encoder = ce.OneHotEncoder(use_cat_names=True)
x_train_encoded = encoder.fit_transform(x_train)
x_val_encoded = encoder.transform(x_val)
x_test_encoded = encoder.transform(x_test)

# %% [markdown]
# ## 2.5. Use scikit-learn to fit a linear regression or ridge regression model
# Fit your model.

# %%
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

selector = SelectKBest(score_func=f_regression, k=15)
X_train_selected = selector.fit_transform(x_train_encoded, y_train)
X_val_selected = selector.transform(x_val_encoded)

for k in range (1, len(x_train_encoded.columns)+1):
    print(f'{k} features')
    
    selector = SelectKBest(score_func=f_regression, k=k)
    X_train_selected = selector.fit_transform(x_train_encoded, y_train)
    X_val_selected = selector.transform(x_val_encoded)


    model = LinearRegression()
    model.fit(X_train_selected, y_train)
    y_pred = model.predict(X_val_selected)
    mae = mean_absolute_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred)
    print(f'Val Mean Absolute Error: ${mae:,.0f}')
    print(f'R Squared = {r2:,.4f} \n')
# Out:
# 1 features
# Val Mean Absolute Error: $33,203
# R Squared = 0.6725
#
# 2 features
# Val Mean Absolute Error: $29,410
# R Squared = 0.7429
#
# 3 features
# Val Mean Absolute Error: $26,847
# R Squared = 0.7840
#
# 4 features
# Val Mean Absolute Error: $25,911
# R Squared = 0.7948
#
# 5 features
# Val Mean Absolute Error: $25,928
# R Squared = 0.7947
#
# 6 features
# Val Mean Absolute Error: $24,681
# R Squared = 0.8083
#
# 7 features
# Val Mean Absolute Error: $24,561
# R Squared = 0.8104
#
# 8 features
# Val Mean Absolute Error: $24,455
# R Squared = 0.8119
#
# 9 features
# Val Mean Absolute Error: $24,472
# R Squared = 0.8118
#
# 10 features
# Val Mean Absolute Error: $22,310
# R Squared = 0.8448
#
# 11 features
# Val Mean Absolute Error: $22,152
# R Squared = 0.8451
#
# 12 features
# Val Mean Absolute Error: $21,936
# R Squared = 0.8505
#
# 13 features
# Val Mean Absolute Error: $21,946
# R Squared = 0.8509
#
# 14 features
# Val Mean Absolute Error: $21,853
# R Squared = 0.8535
#
# 15 features
# Val Mean Absolute Error: $21,481
# R Squared = 0.8574
#
# 16 features
# Val Mean Absolute Error: $21,448
# R Squared = 0.8574
#
# 17 features
# Val Mean Absolute Error: $21,353
# R Squared = 0.8577
#
# 18 features
# Val Mean Absolute Error: $21,346
# R Squared = 0.8578
#
# 19 features
# Val Mean Absolute Error: $21,280
# R Squared = 0.8579
#
# 20 features
# Val Mean Absolute Error: $21,306
# R Squared = 0.8577
#
# 21 features
# Val Mean Absolute Error: $21,249
# R Squared = 0.8580
#
# 22 features
# Val Mean Absolute Error: $20,554
# R Squared = 0.8640
#
# 23 features
# Val Mean Absolute Error: $20,286
# R Squared = 0.8661
#
# 24 features
# Val Mean Absolute Error: $20,284
# R Squared = 0.8660
#
# 25 features
# Val Mean Absolute Error: $20,300
# R Squared = 0.8662
#
# 26 features
# Val Mean Absolute Error: $20,300
# R Squared = 0.8662
#
# 27 features
# Val Mean Absolute Error: $20,392
# R Squared = 0.8650
#
# 28 features
# Val Mean Absolute Error: $20,536
# R Squared = 0.8612
#
# 29 features
# Val Mean Absolute Error: $20,372
# R Squared = 0.8628
#
# 30 features
# Val Mean Absolute Error: $20,377
# R Squared = 0.8629
#
# 31 features
# Val Mean Absolute Error: $20,387
# R Squared = 0.8626
#
# 32 features
# Val Mean Absolute Error: $20,413
# R Squared = 0.8624
#
# 33 features
# Val Mean Absolute Error: $19,956
# R Squared = 0.8684
#
# 34 features
# Val Mean Absolute Error: $19,895
# R Squared = 0.8689
#
# 35 features
# Val Mean Absolute Error: $19,920
# R Squared = 0.8692
#
# 36 features
# Val Mean Absolute Error: $19,920
# R Squared = 0.8692
#
# 37 features
# Val Mean Absolute Error: $19,947
# R Squared = 0.8690
#
# 38 features
# Val Mean Absolute Error: $19,487
# R Squared = 0.8742
#
# 39 features
# Val Mean Absolute Error: $19,653
# R Squared = 0.8728
#
# 40 features
# Val Mean Absolute Error: $19,690
# R Squared = 0.8725
#
# 41 features
# Val Mean Absolute Error: $19,622
# R Squared = 0.8731
#
# 42 features
# Val Mean Absolute Error: $19,524
# R Squared = 0.8745
#
# 43 features
# Val Mean Absolute Error: $19,524
# R Squared = 0.8745
#
# 44 features
# Val Mean Absolute Error: $19,502
# R Squared = 0.8746
#
# 45 features
# Val Mean Absolute Error: $19,467
# R Squared = 0.8756
#
# 46 features
# Val Mean Absolute Error: $19,467
# R Squared = 0.8757
#
# 47 features
# Val Mean Absolute Error: $19,492
# R Squared = 0.8756
#
# 48 features
# Val Mean Absolute Error: $19,512
# R Squared = 0.8756
#
# 49 features
# Val Mean Absolute Error: $19,611
# R Squared = 0.8731
#
# 50 features
# Val Mean Absolute Error: $19,478
# R Squared = 0.8749
#
# 51 features
# Val Mean Absolute Error: $19,503
# R Squared = 0.8748
#
# 52 features
# Val Mean Absolute Error: $19,518
# R Squared = 0.8748
#
# 53 features
# Val Mean Absolute Error: $19,549
# R Squared = 0.8746
#
# 54 features
# Val Mean Absolute Error: $19,468
# R Squared = 0.8767
#
# 55 features
# Val Mean Absolute Error: $19,434
# R Squared = 0.8773
#
# 56 features
# Val Mean Absolute Error: $19,431
# R Squared = 0.8783
#
# 57 features
# Val Mean Absolute Error: $19,439
# R Squared = 0.8785
#
# 58 features
# Val Mean Absolute Error: $19,128
# R Squared = 0.8798
#
# 59 features
# Val Mean Absolute Error: $19,354
# R Squared = 0.8768
#
# 60 features
# Val Mean Absolute Error: $19,354
# R Squared = 0.8768
#
# 61 features
# Val Mean Absolute Error: $19,392
# R Squared = 0.8765
#
# 62 features
# Val Mean Absolute Error: $19,487
# R Squared = 0.8762
#
# 63 features
# Val Mean Absolute Error: $19,489
# R Squared = 0.8758
#
# 64 features
# Val Mean Absolute Error: $19,512
# R Squared = 0.8761
#
# 65 features
# Val Mean Absolute Error: $19,512
# R Squared = 0.8761
#
# 66 features
# Val Mean Absolute Error: $19,511
# R Squared = 0.8761
#
# 67 features
# Val Mean Absolute Error: $19,518
# R Squared = 0.8760
#
# 68 features
# Val Mean Absolute Error: $19,507
# R Squared = 0.8761
#
# 69 features
# Val Mean Absolute Error: $19,506
# R Squared = 0.8760
#
# 70 features
# Val Mean Absolute Error: $19,501
# R Squared = 0.8761
#
# 71 features
# Val Mean Absolute Error: $19,339
# R Squared = 0.8781
#
# 72 features
# Val Mean Absolute Error: $19,313
# R Squared = 0.8786
#
# 73 features
# Val Mean Absolute Error: $19,281
# R Squared = 0.8783
#
# 74 features
# Val Mean Absolute Error: $19,155
# R Squared = 0.8796
#
# 75 features
# Val Mean Absolute Error: $18,691
# R Squared = 0.8839
#
# 76 features
# Val Mean Absolute Error: $18,661
# R Squared = 0.8853
#
# 77 features
# Val Mean Absolute Error: $18,518
# R Squared = 0.8855
#
# 78 features
# Val Mean Absolute Error: $18,520
# R Squared = 0.8855
#
# 79 features
# Val Mean Absolute Error: $18,462
# R Squared = 0.8859
#
# 80 features
# Val Mean Absolute Error: $17,997
# R Squared = 0.8888
#
# 81 features
# Val Mean Absolute Error: $18,024
# R Squared = 0.8890
#
# 82 features
# Val Mean Absolute Error: $18,058
# R Squared = 0.8889
#
# 83 features
# Val Mean Absolute Error: $18,058
# R Squared = 0.8889
#
# 84 features
# Val Mean Absolute Error: $18,059
# R Squared = 0.8892
#
# 85 features
# Val Mean Absolute Error: $18,007
# R Squared = 0.8890
#
# 86 features
# Val Mean Absolute Error: $17,951
# R Squared = 0.8917
#
# 87 features
# Val Mean Absolute Error: $17,939
# R Squared = 0.8914
#
# 88 features
# Val Mean Absolute Error: $17,936
# R Squared = 0.8914
#
# 89 features
# Val Mean Absolute Error: $17,987
# R Squared = 0.8908
#
# 90 features
# Val Mean Absolute Error: $17,987
# R Squared = 0.8909
#
# 91 features
# Val Mean Absolute Error: $17,935
# R Squared = 0.8917
#
# 92 features
# Val Mean Absolute Error: $17,946
# R Squared = 0.8916
#
# 93 features
# Val Mean Absolute Error: $17,950
# R Squared = 0.8916
#
# 94 features
# Val Mean Absolute Error: $17,957
# R Squared = 0.8915
#
# 95 features
# Val Mean Absolute Error: $18,005
# R Squared = 0.8909
#
# 96 features
# Val Mean Absolute Error: $18,063
# R Squared = 0.8906
#
# 97 features
# Val Mean Absolute Error: $18,068
# R Squared = 0.8943
#
# 98 features
# Val Mean Absolute Error: $18,073
# R Squared = 0.8942
#
# 99 features
# Val Mean Absolute Error: $18,073
# R Squared = 0.8942
#
# 100 features
# Val Mean Absolute Error: $18,047
# R Squared = 0.8943
#
# 101 features
# Val Mean Absolute Error: $18,347
# R Squared = 0.8918
#
# 102 features
# Val Mean Absolute Error: $18,334
# R Squared = 0.8917
#
# 103 features
# Val Mean Absolute Error: $18,325
# R Squared = 0.8917
#
# 104 features
# Val Mean Absolute Error: $18,326
# R Squared = 0.8916
#
# 105 features
# Val Mean Absolute Error: $18,308
# R Squared = 0.8918
#
# 106 features
# Val Mean Absolute Error: $18,310
# R Squared = 0.8918
#
# 107 features
# Val Mean Absolute Error: $18,373
# R Squared = 0.8912
#
# 108 features
# Val Mean Absolute Error: $18,582
# R Squared = 0.8888
#
# 109 features
# Val Mean Absolute Error: $18,582
# R Squared = 0.8888
#
# 110 features
# Val Mean Absolute Error: $18,590
# R Squared = 0.8887
#
# 111 features
# Val Mean Absolute Error: $18,597
# R Squared = 0.8887
#
# 112 features
# Val Mean Absolute Error: $18,598
# R Squared = 0.8887
#
# 113 features
# Val Mean Absolute Error: $18,587
# R Squared = 0.8891
#
# 114 features
# Val Mean Absolute Error: $18,463
# R Squared = 0.8898
#
# 115 features
# Val Mean Absolute Error: $18,457
# R Squared = 0.8898
#
# 116 features
# Val Mean Absolute Error: $18,453
# R Squared = 0.8893
#
# 117 features
# Val Mean Absolute Error: $18,426
# R Squared = 0.8894
#
# 118 features
# Val Mean Absolute Error: $18,384
# R Squared = 0.8897
#
# 119 features
# Val Mean Absolute Error: $18,346
# R Squared = 0.8897
#
# 120 features
# Val Mean Absolute Error: $18,589
# R Squared = 0.8813
#
# 121 features
# Val Mean Absolute Error: $18,545
# R Squared = 0.8814
#
# 122 features
# Val Mean Absolute Error: $18,485
# R Squared = 0.8819
#
# 123 features
# Val Mean Absolute Error: $18,525
# R Squared = 0.8817
#
# 124 features
# Val Mean Absolute Error: $18,568
# R Squared = 0.8812
#
# 125 features
# Val Mean Absolute Error: $18,576
# R Squared = 0.8810
#
# 126 features
# Val Mean Absolute Error: $18,509
# R Squared = 0.8814
#
# 127 features
# Val Mean Absolute Error: $18,527
# R Squared = 0.8814
#
# 128 features
# Val Mean Absolute Error: $18,527
# R Squared = 0.8814
#
# 129 features
# Val Mean Absolute Error: $18,535
# R Squared = 0.8813
#
# 130 features
# Val Mean Absolute Error: $18,511
# R Squared = 0.8815
#
# 131 features
# Val Mean Absolute Error: $18,572
# R Squared = 0.8812
#
# 132 features
# Val Mean Absolute Error: $18,581
# R Squared = 0.8812
#
# 133 features
# Val Mean Absolute Error: $18,617
# R Squared = 0.8811
#
# 134 features
# Val Mean Absolute Error: $18,621
# R Squared = 0.8811
#
# 135 features
# Val Mean Absolute Error: $18,625
# R Squared = 0.8810
#
# 136 features
# Val Mean Absolute Error: $18,647
# R Squared = 0.8809
#
# 137 features
# Val Mean Absolute Error: $18,649
# R Squared = 0.8817
#
# 138 features
# Val Mean Absolute Error: $18,659
# R Squared = 0.8815
#
# 139 features
# Val Mean Absolute Error: $18,671
# R Squared = 0.8815
#
# 140 features
# Val Mean Absolute Error: $18,674
# R Squared = 0.8815
#
# 141 features
# Val Mean Absolute Error: $18,670
# R Squared = 0.8815
#
# 142 features
# Val Mean Absolute Error: $18,671
# R Squared = 0.8815
#
# 143 features
# Val Mean Absolute Error: $18,671
# R Squared = 0.8815
#
# 144 features
# Val Mean Absolute Error: $18,650
# R Squared = 0.8814
#
# 145 features
# Val Mean Absolute Error: $18,651
# R Squared = 0.8814
#
# 146 features
# Val Mean Absolute Error: $18,635
# R Squared = 0.8816
#
# 147 features
# Val Mean Absolute Error: $18,679
# R Squared = 0.8816
#
# 148 features
# Val Mean Absolute Error: $18,647
# R Squared = 0.8815
#
# 149 features
# Val Mean Absolute Error: $18,647
# R Squared = 0.8815
#
# 150 features
# Val Mean Absolute Error: $18,500
# R Squared = 0.8823
#
# 151 features
# Val Mean Absolute Error: $18,439
# R Squared = 0.8820
#
# 152 features
# Val Mean Absolute Error: $18,454
# R Squared = 0.8818
#
# 153 features
# Val Mean Absolute Error: $18,542
# R Squared = 0.8817
#
# 154 features
# Val Mean Absolute Error: $18,539
# R Squared = 0.8817
#
# 155 features
# Val Mean Absolute Error: $18,582
# R Squared = 0.8816
#
# 156 features
# Val Mean Absolute Error: $18,571
# R Squared = 0.8819
#
# 157 features
# Val Mean Absolute Error: $18,639
# R Squared = 0.8812
#
# 158 features
# Val Mean Absolute Error: $18,640
# R Squared = 0.8812
#
# 159 features
# Val Mean Absolute Error: $18,635
# R Squared = 0.8813
#
# 160 features
# Val Mean Absolute Error: $18,563
# R Squared = 0.8818
#
# 161 features
# Val Mean Absolute Error: $18,563
# R Squared = 0.8818
#
# 162 features
# Val Mean Absolute Error: $18,583
# R Squared = 0.8816
#
# 163 features
# Val Mean Absolute Error: $18,555
# R Squared = 0.8815
#
# 164 features
# Val Mean Absolute Error: $18,556
# R Squared = 0.8814
#
# 165 features
# Val Mean Absolute Error: $18,570
# R Squared = 0.8814
#
# 166 features
# Val Mean Absolute Error: $18,581
# R Squared = 0.8814
#
# 167 features
# Val Mean Absolute Error: $18,609
# R Squared = 0.8817
#
# 168 features
# Val Mean Absolute Error: $18,609
# R Squared = 0.8817
#
# 169 features
# Val Mean Absolute Error: $18,609
# R Squared = 0.8817
#
# 170 features
# Val Mean Absolute Error: $192,654
# R Squared = -2,975.3939
#
# 171 features
# Val Mean Absolute Error: $18,632
# R Squared = 0.8816
#
# 172 features
# Val Mean Absolute Error: $18,621
# R Squared = 0.8816
#
# 173 features
# Val Mean Absolute Error: $63,997
# R Squared = -201.7212
#
# 174 features
# Val Mean Absolute Error: $486,926
# R Squared = -21,545.4473
#
# 175 features
# Val Mean Absolute Error: $18,629
# R Squared = 0.8816
#
# 176 features
# Val Mean Absolute Error: $18,587
# R Squared = 0.8819
#
# 177 features
# Val Mean Absolute Error: $18,534
# R Squared = 0.8805
#
# 178 features
# Val Mean Absolute Error: $18,546
# R Squared = 0.8804
#
# 179 features
# Val Mean Absolute Error: $18,590
# R Squared = 0.8800
#
# 180 features
# Val Mean Absolute Error: $18,590
# R Squared = 0.8800
#
# 181 features
# Val Mean Absolute Error: $787,496
# R Squared = -58,080.3163
#
# 182 features
# Val Mean Absolute Error: $1,488,935
# R Squared = -212,391.4264
#
# 183 features
# Val Mean Absolute Error: $18,534
# R Squared = 0.8808
#
# 184 features
# Val Mean Absolute Error: $18,551
# R Squared = 0.8789
#
# 185 features
# Val Mean Absolute Error: $18,506
# R Squared = 0.8793
#
# 186 features
# Val Mean Absolute Error: $18,496
# R Squared = 0.8798
#
# 187 features
# Val Mean Absolute Error: $18,494
# R Squared = 0.8797
#
# 188 features
# Val Mean Absolute Error: $18,502
# R Squared = 0.8797
#
# 189 features
# Val Mean Absolute Error: $18,482
# R Squared = 0.8801
#
# 190 features
# Val Mean Absolute Error: $239,752
# R Squared = -4,183.2241
#
# 191 features
# Val Mean Absolute Error: $18,444
# R Squared = 0.8817
#
# 192 features
# Val Mean Absolute Error: $18,603
# R Squared = 0.8799
#
# 193 features
# Val Mean Absolute Error: $18,603
# R Squared = 0.8799
#
# 194 features
# Val Mean Absolute Error: $18,603
# R Squared = 0.8799
#
# 195 features
# Val Mean Absolute Error: $18,569
# R Squared = 0.8801
#
# 196 features
# Val Mean Absolute Error: $18,561
# R Squared = 0.8802
#
# 197 features
# Val Mean Absolute Error: $18,564
# R Squared = 0.8802
#
# 198 features
# Val Mean Absolute Error: $18,564
# R Squared = 0.8802
#
# 199 features
# Val Mean Absolute Error: $209,820
# R Squared = -3,400.2244
#
# 200 features
# Val Mean Absolute Error: $18,564
# R Squared = 0.8802
#
# 201 features
# Val Mean Absolute Error: $18,538
# R Squared = 0.8799
#
# 202 features
# Val Mean Absolute Error: $18,538
# R Squared = 0.8800
#
# 203 features
# Val Mean Absolute Error: $18,429
# R Squared = 0.8813
#
# 204 features
# Val Mean Absolute Error: $18,435
# R Squared = 0.8815
#
# 205 features
# Val Mean Absolute Error: $403,130
# R Squared = -12,684.4762
#
# 206 features
# Val Mean Absolute Error: $745,656
# R Squared = -49,438.2117
#
# 207 features
# Val Mean Absolute Error: $17,908
# R Squared = 0.8895
#
# 208 features
# Val Mean Absolute Error: $17,929
# R Squared = 0.8893
#
# 209 features
# Val Mean Absolute Error: $17,944
# R Squared = 0.8892
#
# 210 features
# Val Mean Absolute Error: $17,942
# R Squared = 0.8893
#
# 211 features
# Val Mean Absolute Error: $17,942
# R Squared = 0.8893
#
# 212 features
# Val Mean Absolute Error: $17,942
# R Squared = 0.8893
#
# 213 features
# Val Mean Absolute Error: $17,942
# R Squared = 0.8893
#
# 214 features
# Val Mean Absolute Error: $17,920
# R Squared = 0.8894
#
# 215 features
# Val Mean Absolute Error: $2,934,276
# R Squared = -713,256.5171
#
# 216 features
# Val Mean Absolute Error: $2,289,626
# R Squared = -459,974.3080
#
# 217 features
# Val Mean Absolute Error: $246,680
# R Squared = -3,723.7482

# %% [markdown]
# ## 2.6. Report validation MAE and $R^2$
#
# What is your model's Mean Absolute Error and $R^2$ score on the validation set? (You are not graded on how high or low your validation scores are.)

# %%
k=80
selector = SelectKBest(score_func=f_regression, k=k)
X_train_selected = selector.fit_transform(x_train_encoded, y_train)
X_val_selected = selector.transform(x_val_encoded)


model = LinearRegression()
model.fit(X_train_selected, y_train)
y_pred = model.predict(X_val_selected)
mae = mean_absolute_error(y_val, y_pred)
print(f'With {k} Features, Validation Mean Absolute Error = ${mae:,.0f} \n')
r2 = r2_score(y_val, y_pred)
print(f'With {k} Features, R Squared = {r2:,.4f} \n')
# Out:
# With 80 Features, Validation Mean Absolute Error = $17,997
#
# With 80 Features, R Squared = 0.8888

# %% [markdown]
# # Stretch Goals, Regression
# - Make at least 2 visualizations to explore relationships between features and target. You may use any visualization library
# - Try at least 3 feature combinations. You may select features manually, or automatically
# - Report validation MAE and $R^2$ for each feature combination you try
# - Report test MAE and $R^2$ for your final model
# - Print or plot the coefficients for the features in your model

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
homes.columns
# Out:
# Index(['1st_Flr_SF', 'Bedroom_AbvGr', 'Bldg_Type', 'Bsmt_Full_Bath',
#        'Bsmt_Half_Bath', 'Central_Air', 'Condition_1', 'Condition_2',
#        'Electrical', 'Exter_Cond', 'Exter_Qual', 'Exterior_1st',
#        'Exterior_2nd', 'Foundation', 'Full_Bath', 'Functional', 'Gr_Liv_Area',
#        'Half_Bath', 'Heating', 'Heating_QC', 'House_Style', 'Kitchen_AbvGr',
#        'Kitchen_Qual', 'Land_Contour', 'Land_Slope', 'Lot_Area', 'Lot_Config',
#        'Lot_Shape', 'MS_SubClass', 'MS_Zoning', 'Mas_Vnr_Type', 'Mo_Sold',
#        'Neighborhood', 'Overall_Cond', 'Overall_Qual', 'Paved_Drive',
#        'Roof_Matl', 'Roof_Style', 'SalePrice', 'Sale_Condition', 'Sale_Type',
#        'Street', 'TotRms_AbvGrd', 'Utilities', 'Year_Built', 'Year_Remod/Add',
#        'Yr_Sold', 'mean'],
#       dtype='object')

# %%
homes['Gr_Liv_Area'].head()
# Out:
# 0    1656
# 1     896
# 2    1329
# 3    2110
# 4    1629
# Name: Gr_Liv_Area, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(24,16))
sns.regplot(y=homes['SalePrice'], x=homes['Gr_Liv_Area'])

# %%
fig, ax = plt.subplots(figsize=(24,16))
ax = sns.scatterplot(y=homes['SalePrice'], x=homes['Gr_Liv_Area'], hue=homes['Neighborhood'], alpha=.5)

# %%
fig, ax = plt.subplots(figsize=(24,16))
ax = sns.scatterplot(y=homes['SalePrice'], x=homes['Gr_Liv_Area'], hue=homes['Yr_Sold'])

# %%
selector = SelectKBest(score_func=f_regression, k=15)
X_train_selected = selector.fit_transform(x_train_encoded, y_train)
X_test_selected = selector.transform(x_test_encoded)

for k in range (1, len(x_train_encoded.columns)+1):
    print(f'{k} features')
    
    selector = SelectKBest(score_func=f_regression, k=k)
    X_train_selected = selector.fit_transform(x_train_encoded, y_train)
    X_test_selected = selector.transform(x_test_encoded)


    model = LinearRegression()
    model.fit(X_train_selected, y_train)
    y_pred = model.predict(X_test_selected)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f'Test Mean Absolute Error: ${mae:,.0f}')
    print(f'Test R Squared = {r2:,.4f} \n')
# Out:
# 1 features
# Test Mean Absolute Error: $34,044
# Test R Squared = 0.5891
#
# 2 features
# Test Mean Absolute Error: $28,339
# Test R Squared = 0.7155
#
# 3 features
# Test Mean Absolute Error: $26,153
# Test R Squared = 0.7550
#
# 4 features
# Test Mean Absolute Error: $26,058
# Test R Squared = 0.7594
#
# 5 features
# Test Mean Absolute Error: $26,049
# Test R Squared = 0.7598
#
# 6 features
# Test Mean Absolute Error: $24,066
# Test R Squared = 0.7855
#
# 7 features
# Test Mean Absolute Error: $24,064
# Test R Squared = 0.7866
#
# 8 features
# Test Mean Absolute Error: $23,702
# Test R Squared = 0.7903
#
# 9 features
# Test Mean Absolute Error: $23,661
# Test R Squared = 0.7918
#
# 10 features
# Test Mean Absolute Error: $22,653
# Test R Squared = 0.8209
#
# 11 features
# Test Mean Absolute Error: $22,769
# Test R Squared = 0.8198
#
# 12 features
# Test Mean Absolute Error: $22,796
# Test R Squared = 0.8225
#
# 13 features
# Test Mean Absolute Error: $22,791
# Test R Squared = 0.8236
#
# 14 features
# Test Mean Absolute Error: $22,279
# Test R Squared = 0.8320
#
# 15 features
# Test Mean Absolute Error: $22,435
# Test R Squared = 0.8298
#
# 16 features
# Test Mean Absolute Error: $22,401
# Test R Squared = 0.8301
#
# 17 features
# Test Mean Absolute Error: $22,415
# Test R Squared = 0.8303
#
# 18 features
# Test Mean Absolute Error: $22,429
# Test R Squared = 0.8299
#
# 19 features
# Test Mean Absolute Error: $22,485
# Test R Squared = 0.8289
#
# 20 features
# Test Mean Absolute Error: $22,464
# Test R Squared = 0.8297
#
# 21 features
# Test Mean Absolute Error: $22,435
# Test R Squared = 0.8300
#
# 22 features
# Test Mean Absolute Error: $22,009
# Test R Squared = 0.8325
#
# 23 features
# Test Mean Absolute Error: $21,901
# Test R Squared = 0.8317
#
# 24 features
# Test Mean Absolute Error: $21,909
# Test R Squared = 0.8316
#
# 25 features
# Test Mean Absolute Error: $21,925
# Test R Squared = 0.8317
#
# 26 features
# Test Mean Absolute Error: $21,926
# Test R Squared = 0.8317
#
# 27 features
# Test Mean Absolute Error: $21,781
# Test R Squared = 0.8313
#
# 28 features
# Test Mean Absolute Error: $21,859
# Test R Squared = 0.8296
#
# 29 features
# Test Mean Absolute Error: $21,833
# Test R Squared = 0.8301
#
# 30 features
# Test Mean Absolute Error: $21,832
# Test R Squared = 0.8305
#
# 31 features
# Test Mean Absolute Error: $21,964
# Test R Squared = 0.8296
#
# 32 features
# Test Mean Absolute Error: $21,992
# Test R Squared = 0.8293
#
# 33 features
# Test Mean Absolute Error: $21,582
# Test R Squared = 0.8359
#
# 34 features
# Test Mean Absolute Error: $21,779
# Test R Squared = 0.8354
#
# 35 features
# Test Mean Absolute Error: $21,530
# Test R Squared = 0.8380
#
# 36 features
# Test Mean Absolute Error: $21,530
# Test R Squared = 0.8380
#
# 37 features
# Test Mean Absolute Error: $21,479
# Test R Squared = 0.8382
#
# 38 features
# Test Mean Absolute Error: $21,057
# Test R Squared = 0.8447
#
# 39 features
# Test Mean Absolute Error: $21,224
# Test R Squared = 0.8439
#
# 40 features
# Test Mean Absolute Error: $21,200
# Test R Squared = 0.8440
#
# 41 features
# Test Mean Absolute Error: $21,149
# Test R Squared = 0.8441
#
# 42 features
# Test Mean Absolute Error: $21,090
# Test R Squared = 0.8447
#
# 43 features
# Test Mean Absolute Error: $21,078
# Test R Squared = 0.8449
#
# 44 features
# Test Mean Absolute Error: $21,082
# Test R Squared = 0.8449
#
# 45 features
# Test Mean Absolute Error: $21,145
# Test R Squared = 0.8467
#
# 46 features
# Test Mean Absolute Error: $21,144
# Test R Squared = 0.8467
#
# 47 features
# Test Mean Absolute Error: $21,091
# Test R Squared = 0.8471
#
# 48 features
# Test Mean Absolute Error: $21,097
# Test R Squared = 0.8470
#
# 49 features
# Test Mean Absolute Error: $21,062
# Test R Squared = 0.8488
#
# 50 features
# Test Mean Absolute Error: $20,737
# Test R Squared = 0.8523
#
# 51 features
# Test Mean Absolute Error: $20,721
# Test R Squared = 0.8525
#
# 52 features
# Test Mean Absolute Error: $20,698
# Test R Squared = 0.8527
#
# 53 features
# Test Mean Absolute Error: $20,626
# Test R Squared = 0.8536
#
# 54 features
# Test Mean Absolute Error: $20,328
# Test R Squared = 0.8537
#
# 55 features
# Test Mean Absolute Error: $20,306
# Test R Squared = 0.8545
#
# 56 features
# Test Mean Absolute Error: $20,264
# Test R Squared = 0.8544
#
# 57 features
# Test Mean Absolute Error: $20,209
# Test R Squared = 0.8548
#
# 58 features
# Test Mean Absolute Error: $20,157
# Test R Squared = 0.8548
#
# 59 features
# Test Mean Absolute Error: $20,253
# Test R Squared = 0.8521
#
# 60 features
# Test Mean Absolute Error: $20,279
# Test R Squared = 0.8520
#
# 61 features
# Test Mean Absolute Error: $20,331
# Test R Squared = 0.8519
#
# 62 features
# Test Mean Absolute Error: $20,402
# Test R Squared = 0.8508
#
# 63 features
# Test Mean Absolute Error: $20,409
# Test R Squared = 0.8515
#
# 64 features
# Test Mean Absolute Error: $20,471
# Test R Squared = 0.8510
#
# 65 features
# Test Mean Absolute Error: $20,469
# Test R Squared = 0.8509
#
# 66 features
# Test Mean Absolute Error: $20,464
# Test R Squared = 0.8508
#
# 67 features
# Test Mean Absolute Error: $20,464
# Test R Squared = 0.8508
#
# 68 features
# Test Mean Absolute Error: $20,461
# Test R Squared = 0.8508
#
# 69 features
# Test Mean Absolute Error: $20,465
# Test R Squared = 0.8508
#
# 70 features
# Test Mean Absolute Error: $20,454
# Test R Squared = 0.8508
#
# 71 features
# Test Mean Absolute Error: $20,387
# Test R Squared = 0.8525
#
# 72 features
# Test Mean Absolute Error: $20,322
# Test R Squared = 0.8528
#
# 73 features
# Test Mean Absolute Error: $20,275
# Test R Squared = 0.8525
#
# 74 features
# Test Mean Absolute Error: $20,250
# Test R Squared = 0.8523
#
# 75 features
# Test Mean Absolute Error: $19,883
# Test R Squared = 0.8575
#
# 76 features
# Test Mean Absolute Error: $19,889
# Test R Squared = 0.8583
#
# 77 features
# Test Mean Absolute Error: $19,632
# Test R Squared = 0.8608
#
# 78 features
# Test Mean Absolute Error: $19,620
# Test R Squared = 0.8608
#
# 79 features
# Test Mean Absolute Error: $19,644
# Test R Squared = 0.8608
#
# 80 features
# Test Mean Absolute Error: $18,941
# Test R Squared = 0.8654
#
# 81 features
# Test Mean Absolute Error: $19,032
# Test R Squared = 0.8643
#
# 82 features
# Test Mean Absolute Error: $19,042
# Test R Squared = 0.8646
#
# 83 features
# Test Mean Absolute Error: $19,042
# Test R Squared = 0.8646
#
# 84 features
# Test Mean Absolute Error: $19,011
# Test R Squared = 0.8654
#
# 85 features
# Test Mean Absolute Error: $19,070
# Test R Squared = 0.8659
#
# 86 features
# Test Mean Absolute Error: $354,796
# Test R Squared = -6,886.8049
#
# 87 features
# Test Mean Absolute Error: $19,201
# Test R Squared = 0.8643
#
# 88 features
# Test Mean Absolute Error: $8,289,541
# Test R Squared = -4,179,521.9449
#
# 89 features
# Test Mean Absolute Error: $463,199
# Test R Squared = -12,048.4819
#
# 90 features
# Test Mean Absolute Error: $1,542,328
# Test R Squared = -141,770.6463
#
# 91 features
# Test Mean Absolute Error: $19,165
# Test R Squared = 0.8654
#
# 92 features
# Test Mean Absolute Error: $563,665
# Test R Squared = -18,121.0758
#
# 93 features
# Test Mean Absolute Error: $19,153
# Test R Squared = 0.8659
#
# 94 features
# Test Mean Absolute Error: $118,005
# Test R Squared = -596.3549
#
# 95 features
# Test Mean Absolute Error: $19,170
# Test R Squared = 0.8656
#
# 96 features
# Test Mean Absolute Error: $390,485
# Test R Squared = -8,426.4140
#
# 97 features
# Test Mean Absolute Error: $18,607
# Test R Squared = 0.8742
#
# 98 features
# Test Mean Absolute Error: $18,606
# Test R Squared = 0.8744
#
# 99 features
# Test Mean Absolute Error: $18,606
# Test R Squared = 0.8744
#
# 100 features
# Test Mean Absolute Error: $18,750
# Test R Squared = 0.8736
#
# 101 features
# Test Mean Absolute Error: $18,613
# Test R Squared = 0.8768
#
# 102 features
# Test Mean Absolute Error: $18,611
# Test R Squared = 0.8765
#
# 103 features
# Test Mean Absolute Error: $18,671
# Test R Squared = 0.8756
#
# 104 features
# Test Mean Absolute Error: $18,671
# Test R Squared = 0.8756
#
# 105 features
# Test Mean Absolute Error: $18,681
# Test R Squared = 0.8755
#
# 106 features
# Test Mean Absolute Error: $18,697
# Test R Squared = 0.8751
#
# 107 features
# Test Mean Absolute Error: $18,669
# Test R Squared = 0.8755
#
# 108 features
# Test Mean Absolute Error: $18,493
# Test R Squared = 0.8776
#
# 109 features
# Test Mean Absolute Error: $18,493
# Test R Squared = 0.8776
#
# 110 features
# Test Mean Absolute Error: $18,510
# Test R Squared = 0.8775
#
# 111 features
# Test Mean Absolute Error: $35,264
# Test R Squared = -16.3357
#
# 112 features
# Test Mean Absolute Error: $18,485
# Test R Squared = 0.8777
#
# 113 features
# Test Mean Absolute Error: $18,471
# Test R Squared = 0.8775
#
# 114 features
# Test Mean Absolute Error: $18,118
# Test R Squared = 0.8807
#
# 115 features
# Test Mean Absolute Error: $18,115
# Test R Squared = 0.8803
#
# 116 features
# Test Mean Absolute Error: $17,945
# Test R Squared = 0.8811
#
# 117 features
# Test Mean Absolute Error: $17,944
# Test R Squared = 0.8810
#
# 118 features
# Test Mean Absolute Error: $17,927
# Test R Squared = 0.8810
#
# 119 features
# Test Mean Absolute Error: $17,923
# Test R Squared = 0.8810
#
# 120 features
# Test Mean Absolute Error: $18,065
# Test R Squared = 0.8799
#
# 121 features
# Test Mean Absolute Error: $18,182
# Test R Squared = 0.8793
#
# 122 features
# Test Mean Absolute Error: $18,196
# Test R Squared = 0.8794
#
# 123 features
# Test Mean Absolute Error: $18,180
# Test R Squared = 0.8795
#
# 124 features
# Test Mean Absolute Error: $18,150
# Test R Squared = 0.8799
#
# 125 features
# Test Mean Absolute Error: $18,223
# Test R Squared = 0.8791
#
# 126 features
# Test Mean Absolute Error: $18,099
# Test R Squared = 0.8804
#
# 127 features
# Test Mean Absolute Error: $18,149
# Test R Squared = 0.8799
#
# 128 features
# Test Mean Absolute Error: $18,149
# Test R Squared = 0.8799
#
# 129 features
# Test Mean Absolute Error: $18,134
# Test R Squared = 0.8800
#
# 130 features
# Test Mean Absolute Error: $18,121
# Test R Squared = 0.8802
#
# 131 features
# Test Mean Absolute Error: $18,139
# Test R Squared = 0.8797
#
# 132 features
# Test Mean Absolute Error: $18,150
# Test R Squared = 0.8796
#
# 133 features
# Test Mean Absolute Error: $18,254
# Test R Squared = 0.8785
#
# 134 features
# Test Mean Absolute Error: $18,268
# Test R Squared = 0.8785
#
# 135 features
# Test Mean Absolute Error: $18,251
# Test R Squared = 0.8790
#
# 136 features
# Test Mean Absolute Error: $18,521
# Test R Squared = 0.8758
#
# 137 features
# Test Mean Absolute Error: $18,691
# Test R Squared = 0.8743
#
# 138 features
# Test Mean Absolute Error: $18,697
# Test R Squared = 0.8743
#
# 139 features
# Test Mean Absolute Error: $18,631
# Test R Squared = 0.8748
#
# 140 features
# Test Mean Absolute Error: $18,634
# Test R Squared = 0.8746
#
# 141 features
# Test Mean Absolute Error: $18,628
# Test R Squared = 0.8747
#
# 142 features
# Test Mean Absolute Error: $18,628
# Test R Squared = 0.8746
#
# 143 features
# Test Mean Absolute Error: $18,628
# Test R Squared = 0.8746
#
# 144 features
# Test Mean Absolute Error: $18,647
# Test R Squared = 0.8748
#
# 145 features
# Test Mean Absolute Error: $18,649
# Test R Squared = 0.8747
#
# 146 features
# Test Mean Absolute Error: $18,685
# Test R Squared = 0.8745
#
# 147 features
# Test Mean Absolute Error: $18,653
# Test R Squared = 0.8749
#
# 148 features
# Test Mean Absolute Error: $18,580
# Test R Squared = 0.8759
#
# 149 features
# Test Mean Absolute Error: $18,580
# Test R Squared = 0.8759
#
# 150 features
# Test Mean Absolute Error: $18,625
# Test R Squared = 0.8745
#
# 151 features
# Test Mean Absolute Error: $18,665
# Test R Squared = 0.8740
#
# 152 features
# Test Mean Absolute Error: $18,686
# Test R Squared = 0.8740
#
# 153 features
# Test Mean Absolute Error: $18,736
# Test R Squared = 0.8733
#
# 154 features
# Test Mean Absolute Error: $18,735
# Test R Squared = 0.8734
#
# 155 features
# Test Mean Absolute Error: $18,791
# Test R Squared = 0.8730
#
# 156 features
# Test Mean Absolute Error: $18,792
# Test R Squared = 0.8731
#
# 157 features
# Test Mean Absolute Error: $18,821
# Test R Squared = 0.8728
#
# 158 features
# Test Mean Absolute Error: $18,825
# Test R Squared = 0.8727
#
# 159 features
# Test Mean Absolute Error: $18,843
# Test R Squared = 0.8726
#
# 160 features
# Test Mean Absolute Error: $18,792
# Test R Squared = 0.8730
#
# 161 features
# Test Mean Absolute Error: $18,792
# Test R Squared = 0.8730
#
# 162 features
# Test Mean Absolute Error: $18,775
# Test R Squared = 0.8732
#
# 163 features
# Test Mean Absolute Error: $18,604
# Test R Squared = 0.8756
#
# 164 features
# Test Mean Absolute Error: $18,611
# Test R Squared = 0.8756
#
# 165 features
# Test Mean Absolute Error: $92,305
# Test R Squared = -331.2959
#
# 166 features
# Test Mean Absolute Error: $18,593
# Test R Squared = 0.8757
#
# 167 features
# Test Mean Absolute Error: $18,503
# Test R Squared = 0.8762
#
# 168 features
# Test Mean Absolute Error: $18,503
# Test R Squared = 0.8762
#
# 169 features
# Test Mean Absolute Error: $1,194,576
# Test R Squared = -84,518.0695
#
# 170 features
# Test Mean Absolute Error: $4,350,344
# Test R Squared = -837,584.6766
#
# 171 features
# Test Mean Absolute Error: $18,455
# Test R Squared = 0.8765
#
# 172 features
# Test Mean Absolute Error: $18,438
# Test R Squared = 0.8766
#
# 173 features
# Test Mean Absolute Error: $441,356
# Test R Squared = -4,747.8086
#
# 174 features
# Test Mean Absolute Error: $5,553,339
# Test R Squared = -960,520.4762
#
# 175 features
# Test Mean Absolute Error: $18,451
# Test R Squared = 0.8765
#
# 176 features
# Test Mean Absolute Error: $18,463
# Test R Squared = 0.8766
#
# 177 features
# Test Mean Absolute Error: $18,369
# Test R Squared = 0.8789
#
# 178 features
# Test Mean Absolute Error: $18,332
# Test R Squared = 0.8792
#
# 179 features
# Test Mean Absolute Error: $18,320
# Test R Squared = 0.8792
#
# 180 features
# Test Mean Absolute Error: $18,320
# Test R Squared = 0.8792
#
# 181 features
# Test Mean Absolute Error: $5,751,952
# Test R Squared = -745,420.3251
#
# 182 features
# Test Mean Absolute Error: $7,227,128
# Test R Squared = -1,112,048.3045
#
# 183 features
# Test Mean Absolute Error: $18,275
# Test R Squared = 0.8796
#
# 184 features
# Test Mean Absolute Error: $18,330
# Test R Squared = 0.8797
#
# 185 features
# Test Mean Absolute Error: $18,346
# Test R Squared = 0.8796
#
# 186 features
# Test Mean Absolute Error: $18,566
# Test R Squared = 0.8776
#
# 187 features
# Test Mean Absolute Error: $18,564
# Test R Squared = 0.8776
#
# 188 features
# Test Mean Absolute Error: $18,564
# Test R Squared = 0.8776
#
# 189 features
# Test Mean Absolute Error: $18,545
# Test R Squared = 0.8777
#
# 190 features
# Test Mean Absolute Error: $3,784,809
# Test R Squared = -563,748.6032
#
# 191 features
# Test Mean Absolute Error: $18,494
# Test R Squared = 0.8783
#
# 192 features
# Test Mean Absolute Error: $18,465
# Test R Squared = 0.8785
#
# 193 features
# Test Mean Absolute Error: $18,465
# Test R Squared = 0.8785
#
# 194 features
# Test Mean Absolute Error: $18,465
# Test R Squared = 0.8785
#
# 195 features
# Test Mean Absolute Error: $18,364
# Test R Squared = 0.8794
#
# 196 features
# Test Mean Absolute Error: $18,425
# Test R Squared = 0.8783
#
# 197 features
# Test Mean Absolute Error: $18,435
# Test R Squared = 0.8782
#
# 198 features
# Test Mean Absolute Error: $18,435
# Test R Squared = 0.8782
#
# 199 features
# Test Mean Absolute Error: $1,141,748
# Test R Squared = -25,883.4233
#
# 200 features
# Test Mean Absolute Error: $18,430
# Test R Squared = 0.8783
#
# 201 features
# Test Mean Absolute Error: $18,323
# Test R Squared = 0.8807
#
# 202 features
# Test Mean Absolute Error: $18,321
# Test R Squared = 0.8807
#
# 203 features
# Test Mean Absolute Error: $18,440
# Test R Squared = 0.8803
#
# 204 features
# Test Mean Absolute Error: $18,472
# Test R Squared = 0.8816
#
# 205 features
# Test Mean Absolute Error: $12,935,747
# Test R Squared = -8,221,404.3371
#
# 206 features
# Test Mean Absolute Error: $3,971,027
# Test R Squared = -318,537.6764
#
# 207 features
# Test Mean Absolute Error: $18,052
# Test R Squared = 0.8837
#
# 208 features
# Test Mean Absolute Error: $18,118
# Test R Squared = 0.8823
#
# 209 features
# Test Mean Absolute Error: $18,147
# Test R Squared = 0.8822
#
# 210 features
# Test Mean Absolute Error: $18,113
# Test R Squared = 0.8825
#
# 211 features
# Test Mean Absolute Error: $18,113
# Test R Squared = 0.8825
#
# 212 features
# Test Mean Absolute Error: $18,113
# Test R Squared = 0.8825
#
# 213 features
# Test Mean Absolute Error: $18,113
# Test R Squared = 0.8825
#
# 214 features
# Test Mean Absolute Error: $18,209
# Test R Squared = 0.8817
#
# 215 features
# Test Mean Absolute Error: $21,721,583
# Test R Squared = -17,899,529.0378
#
# 216 features
# Test Mean Absolute Error: $8,734,298
# Test R Squared = -1,843,290.5887
#
# 217 features
# Test Mean Absolute Error: $16,037,879
# Test R Squared = -14,805,766.0902

# %% [markdown]
# # Data Dictionary
#
# Here's a description of the data fields:
#
# ```
# 1st_Flr_SF: First Floor square feet
#
# Bedroom_AbvGr: Bedrooms above grade (does NOT include basement bedrooms)
#
# Bldg_Type: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# Bsmt_Half_Bath: Basement half bathrooms
#
# Bsmt_Full_Bath: Basement full bathrooms
#
# Central_Air: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Condition_1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition_2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
#  Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
#  Exter_Cond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
#  Exter_Qual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Exterior_1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior_2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# Full_Bath: Full bathrooms above grade
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Gr_Liv_Area: Above grade (ground) living area square feet
#
# Half_Bath: Half baths above grade
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# Heating_QC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# House_Style: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# Kitchen_AbvGr: Kitchens above grade
#
# Kitchen_Qual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Land_Slope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Lot_Area: Lot size in square feet
#
# Lot_Config: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# Lot_Shape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# MS_SubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MS_Zoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# Mas_Vnr_Type: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# Mo_Sold: Month Sold (MM)
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Overall_Cond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# Overall_Qual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# Paved_Drive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# Roof_Matl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Roof_Style: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# SalePrice: the sales price for each house
#
# Sale_Condition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)
#
# Sale_Type: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# TotRms_AbvGrd: Total rooms above grade (does not include bathrooms)
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# Year_Built: Original construction date
#
# Year_Remod/Add: Remodel date (same as construction date if no remodeling or additions)
#
# Yr_Sold: Year Sold (YYYY)
#
# ```
